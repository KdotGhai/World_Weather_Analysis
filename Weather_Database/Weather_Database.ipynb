# %% [markdown]
# **DELIVERABLE 1**

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import requests
requests.__version__
import time
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy


from config import *

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
#print("Beginning Data Retrieval     ")
#print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(10)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        #Get City Description such as cloudy, broken clouds, rain, sunny, etc.
        city_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
#print("-----------------------------")
#print("Data Retrieval Complete      ")
#print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | verkhniye tatyshly
# Processing Record 2 of Set 1 | vaitupu
# Processing Record 3 of Set 1 | tezu
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | el limon
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | xudat
# Processing Record 11 of Set 1 | nigde
# Processing Record 12 of Set 1 | tsihombe
# Processing Record 13 of Set 1 | kazanka
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | ongandjera
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | amderma
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | fare
# Processing Record 22 of Set 1 | chokwe
# Processing Record 23 of Set 1 | lephepe
# Processing Record 24 of Set 1 | stoyba
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | vardo
# Processing Record 27 of Set 1 | lerwick
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | guerrero negro
# Processing Record 30 of Set 1 | dicamay
# Processing Record 31 of Set 1 | sharan
# Processing Record 32 of Set 1 | tawkar
# Processing Record 33 of Set 1 | chuzhou
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | russell
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | taolanaro
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | samusu
# Processing Record 46 of Set 1 | hastings
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | jardim
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | hami
# Processing Record 1 of Set 2 | flinders
# Processing Record 2 of Set 2 | kismayo
# Processing Record 3 of Set 2 | pocatello
# Processing Record 4 of Set 2 | bathsheba
# Processing Record 5 of Set 2 | taburi
# Processing Record 6 of Set 2 | bundaberg
# Processing Record 7 of Set 2 | yakeshi
# Processing Record 8 of Set 2 | kloulklubed
# Processing Record 9 of Set 2 | dinsor
# Processing Record 10 of Set 2 | saldanha
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | fort nelson
# Processing Record 14 of Set 2 | kudahuvadhoo
# Processing Record 15 of Set 2 | innisfail
# Processing Record 16 of Set 2 | ust-kamchatsk
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | tamandare
# Processing Record 20 of Set 2 | ixtapa
# Processing Record 21 of Set 2 | marcona
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | mankovo-kalitvenskoye
# Processing Record 24 of Set 2 | suzun
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | illoqqortoormiut
# Processing Record 27 of Set 2 | abbeville
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | walvis bay
# Processing Record 30 of Set 2 | yulara
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | alenquer
# Processing Record 33 of Set 2 | tanout
# Processing Record 34 of Set 2 | kasangulu
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | bereda
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | conde
# Processing Record 39 of Set 2 | sentyabrskiy
# Processing Record 40 of Set 2 | atar
# Processing Record 41 of Set 2 | phan rang
# Processing Record 42 of Set 2 | paamiut
# Processing Record 43 of Set 2 | chino hills
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | andilamena
# Processing Record 46 of Set 2 | quatre cocos
# Processing Record 47 of Set 2 | otradnoye
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | drayton valley
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | avera
# Processing Record 2 of Set 3 | plouzane
# Processing Record 3 of Set 3 | lebanon
# Processing Record 4 of Set 3 | mildura
# Processing Record 5 of Set 3 | mayo
# Processing Record 6 of Set 3 | balykshi
# Processing Record 7 of Set 3 | potosi
# Processing Record 8 of Set 3 | mahon
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | kropotkin
# Processing Record 11 of Set 3 | belushya guba
# Processing Record 12 of Set 3 | gorazde
# Processing Record 13 of Set 3 | tunduru
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | zagreb
# Processing Record 16 of Set 3 | sibolga
# Processing Record 17 of Set 3 | pa daet
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | ancud
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | kahului
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | izhma
# Processing Record 25 of Set 3 | skjervoy
# Processing Record 26 of Set 3 | tavricheskoye
# Processing Record 27 of Set 3 | esperance
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | dunedin
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | ban nahin
# Processing Record 32 of Set 3 | caravelas
# Processing Record 33 of Set 3 | inderborskiy
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | vestbygda
# Processing Record 36 of Set 3 | bandarbeyla
# Processing Record 37 of Set 3 | santa cruz del norte
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | boyolangu
# Processing Record 40 of Set 3 | kalmunai
# Processing Record 41 of Set 3 | yeppoon
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | aketi
# Processing Record 44 of Set 3 | farafangana
# Processing Record 45 of Set 3 | nouadhibou
# Processing Record 46 of Set 3 | srednekolymsk
# Processing Record 47 of Set 3 | chapleau
# Processing Record 48 of Set 3 | bang len
# Processing Record 49 of Set 3 | karaul
# Processing Record 50 of Set 3 | gogrial
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | nome
# Processing Record 3 of Set 4 | ranong
# Processing Record 4 of Set 4 | katsuura
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | nguiu
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | parker
# Processing Record 10 of Set 4 | brownfield
# Processing Record 11 of Set 4 | labutta
# Processing Record 12 of Set 4 | port alfred
# Processing Record 13 of Set 4 | nizhneyansk
# Processing Record 14 of Set 4 | voh
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | baicheng
# Processing Record 17 of Set 4 | bosaso
# Processing Record 18 of Set 4 | preobrazhenskaya
# Processing Record 19 of Set 4 | isangel
# Processing Record 20 of Set 4 | mataura
# Processing Record 21 of Set 4 | luanda
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | yumen
# Processing Record 24 of Set 4 | arcata
# Processing Record 25 of Set 4 | labuhan
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | provideniya
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | kavaratti
# Processing Record 30 of Set 4 | mehamn
# Processing Record 31 of Set 4 | port hedland
# Processing Record 32 of Set 4 | kaitong
# Processing Record 33 of Set 4 | bethel
# Processing Record 34 of Set 4 | kapaa
# Processing Record 35 of Set 4 | quirinopolis
# Processing Record 36 of Set 4 | dingwall
# Processing Record 37 of Set 4 | rungata
# Processing Record 38 of Set 4 | grand river south east
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | egvekinot
# Processing Record 41 of Set 4 | aykhal
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | vila franca do campo
# Processing Record 45 of Set 4 | nuevo laredo
# Processing Record 46 of Set 4 | inhambane
# Processing Record 47 of Set 4 | rayadrug
# Processing Record 48 of Set 4 | pangnirtung
# Processing Record 49 of Set 4 | myitkyina
# Processing Record 50 of Set 4 | namatanai
# Processing Record 1 of Set 5 | coihaique
# Processing Record 2 of Set 5 | kruisfontein
# Processing Record 3 of Set 5 | lolua
# Processing Record 4 of Set 5 | katobu
# Processing Record 5 of Set 5 | florianopolis
# Processing Record 6 of Set 5 | calama
# Processing Record 7 of Set 5 | mys shmidta
# Processing Record 8 of Set 5 | aquiraz
# Processing Record 9 of Set 5 | marawi
# Processing Record 10 of Set 5 | kommunisticheskiy
# Processing Record 11 of Set 5 | attawapiskat
# Processing Record 12 of Set 5 | itarema
# Processing Record 13 of Set 5 | jibuti
# Processing Record 14 of Set 5 | samarai
# Processing Record 15 of Set 5 | chumikan
# Processing Record 16 of Set 5 | grande prairie
# Processing Record 17 of Set 5 | la ronge
# Processing Record 18 of Set 5 | noshiro
# Processing Record 19 of Set 5 | pokosnoye
# Processing Record 20 of Set 5 | elk
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | sibut
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | saleaula
# Processing Record 25 of Set 5 | sambava
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | vihti
# Processing Record 29 of Set 5 | barentsburg
# Processing Record 30 of Set 5 | huinan
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | buique
# Processing Record 33 of Set 5 | jaque
# Processing Record 34 of Set 5 | esna
# Processing Record 35 of Set 5 | suao
# Processing Record 36 of Set 5 | karratha
# Processing Record 37 of Set 5 | biloela
# Processing Record 38 of Set 5 | vao
# Processing Record 39 of Set 5 | port lincoln
# Processing Record 40 of Set 5 | aksu
# Processing Record 41 of Set 5 | tecoanapa
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | gornorechenskiy
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | severobaykalsk
# Processing Record 46 of Set 5 | nador
# Processing Record 47 of Set 5 | pringsewu
# Processing Record 48 of Set 5 | chabahar
# Processing Record 49 of Set 5 | tome-acu
# Processing Record 50 of Set 5 | raahe
# Processing Record 1 of Set 6 | dong hoi
# Processing Record 2 of Set 6 | farah
# Processing Record 3 of Set 6 | henties bay
# Processing Record 4 of Set 6 | shevchenkove
# Processing Record 5 of Set 6 | imbituba
# Processing Record 6 of Set 6 | kamenskoye
# Processing Record 7 of Set 6 | rio grande
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | taoudenni
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | rodrigues alves
# Processing Record 12 of Set 6 | santa marta
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | buala
# Processing Record 15 of Set 6 | tiznit
# Processing Record 16 of Set 6 | saint-louis
# Processing Record 17 of Set 6 | longlac
# Processing Record 18 of Set 6 | bilibino
# Processing Record 19 of Set 6 | grand centre
# Processing Record 20 of Set 6 | castro
# Processing Record 21 of Set 6 | luwingu
# Processing Record 22 of Set 6 | malwan
# Processing Record 23 of Set 6 | ottawa
# Processing Record 24 of Set 6 | puerto escondido
# Processing Record 25 of Set 6 | pitimbu
# Processing Record 26 of Set 6 | goderich
# Processing Record 27 of Set 6 | broome
# Processing Record 28 of Set 6 | fairbanks
# Processing Record 29 of Set 6 | komsomolskiy
# Processing Record 30 of Set 6 | baghmara
# Processing Record 31 of Set 6 | agva
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | waingapu
# Processing Record 34 of Set 6 | eyrarbakki
# Processing Record 35 of Set 6 | yambio
# Processing Record 36 of Set 6 | tartki
# Processing Record 37 of Set 6 | ceyhan
# Processing Record 38 of Set 6 | pevek
# Processing Record 39 of Set 6 | port macquarie
# Processing Record 40 of Set 6 | luderitz
# Processing Record 41 of Set 6 | aswan
# Processing Record 42 of Set 6 | markova
# Processing Record 43 of Set 6 | san pedro
# Processing Record 44 of Set 6 | minas novas
# Processing Record 45 of Set 6 | taree
# Processing Record 46 of Set 6 | halalo
# Processing Record 47 of Set 6 | cobadin
# Processing Record 48 of Set 6 | escanaba
# Processing Record 49 of Set 6 | samalaeulu
# Processing Record 50 of Set 6 | poum
# Processing Record 1 of Set 7 | minsk
# Processing Record 2 of Set 7 | mount gambier
# Processing Record 3 of Set 7 | hidalgotitlan
# Processing Record 4 of Set 7 | talnakh
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | mucurici
# Processing Record 7 of Set 7 | rusape
# Processing Record 8 of Set 7 | toliary
# Processing Record 9 of Set 7 | bud
# Processing Record 10 of Set 7 | pasighat
# Processing Record 11 of Set 7 | spring hill
# Processing Record 12 of Set 7 | asau
# Processing Record 13 of Set 7 | agua verde
# Processing Record 14 of Set 7 | clyde river
# Processing Record 15 of Set 7 | petionville
# Processing Record 16 of Set 7 | holland
# Processing Record 17 of Set 7 | maksi
# Processing Record 18 of Set 7 | kenai
# Processing Record 19 of Set 7 | namibe
# Processing Record 20 of Set 7 | that phanom
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | gazli
# Processing Record 23 of Set 7 | lorengau
# Processing Record 24 of Set 7 | ilulissat
# Processing Record 25 of Set 7 | ijaki
# Processing Record 26 of Set 7 | san rafael
# Processing Record 27 of Set 7 | faanui
# Processing Record 28 of Set 7 | kulhudhuffushi
# Processing Record 29 of Set 7 | lufilufi
# Processing Record 30 of Set 7 | neijiang
# Processing Record 31 of Set 7 | valdivia
# Processing Record 32 of Set 7 | ostrovnoy
# Processing Record 33 of Set 7 | nivala
# Processing Record 34 of Set 7 | kontagora
# Processing Record 35 of Set 7 | polyarnyy
# Processing Record 36 of Set 7 | karatuzskoye
# Processing Record 37 of Set 7 | nanyang
# Processing Record 38 of Set 7 | igrim
# Processing Record 39 of Set 7 | airai
# Processing Record 40 of Set 7 | lagos
# Processing Record 41 of Set 7 | maraa
# Processing Record 42 of Set 7 | neiafu
# Processing Record 43 of Set 7 | yuci
# Processing Record 44 of Set 7 | bonthe
# Processing Record 45 of Set 7 | novoagansk
# Processing Record 46 of Set 7 | bubaque
# Processing Record 47 of Set 7 | alofi
# Processing Record 48 of Set 7 | leh
# Processing Record 49 of Set 7 | gimli
# Processing Record 50 of Set 7 | severo-kurilsk
# Processing Record 1 of Set 8 | tainan
# Processing Record 2 of Set 8 | nago
# Processing Record 3 of Set 8 | chuy
# Processing Record 4 of Set 8 | kaitangata
# Processing Record 5 of Set 8 | narsaq
# Processing Record 6 of Set 8 | necochea
# Processing Record 7 of Set 8 | kurchum
# Processing Record 8 of Set 8 | santa helena de goias
# Processing Record 9 of Set 8 | tazovskiy
# Processing Record 10 of Set 8 | jalingo
# Processing Record 11 of Set 8 | tual
# Processing Record 12 of Set 8 | pangody
# Processing Record 13 of Set 8 | whitehorse
# Processing Record 14 of Set 8 | qabaqcol
# Processing Record 15 of Set 8 | palabuhanratu
# Processing Record 16 of Set 8 | bressanone
# Processing Record 17 of Set 8 | hem
# Processing Record 18 of Set 8 | coquimbo
# Processing Record 19 of Set 8 | vostok
# Processing Record 20 of Set 8 | goundam
# Processing Record 21 of Set 8 | jinxiang
# Processing Record 22 of Set 8 | salalah
# Processing Record 23 of Set 8 | wattegama
# Processing Record 24 of Set 8 | ambulu
# Processing Record 25 of Set 8 | mullaitivu
# Processing Record 26 of Set 8 | barwani
# Processing Record 27 of Set 8 | maku
# Processing Record 28 of Set 8 | praya
# Processing Record 29 of Set 8 | saint anthony
# Processing Record 30 of Set 8 | santa fe
# Processing Record 31 of Set 8 | springbok
# Processing Record 32 of Set 8 | vanimo
# Processing Record 33 of Set 8 | grand forks
# Processing Record 34 of Set 8 | lumby
# Processing Record 35 of Set 8 | dwarka
# Processing Record 36 of Set 8 | soe
# Processing Record 37 of Set 8 | port hardy
# Processing Record 38 of Set 8 | stamsund
# Processing Record 39 of Set 8 | freeport
# Processing Record 40 of Set 8 | fort saint james
# Processing Record 41 of Set 8 | strazica
# Processing Record 42 of Set 8 | broken hill
# Processing Record 43 of Set 8 | tuatapere
# Processing Record 44 of Set 8 | high level
# Processing Record 45 of Set 8 | antalaha
# Processing Record 46 of Set 8 | taywarah
# Processing Record 47 of Set 8 | george town
# Processing Record 48 of Set 8 | humaita
# Processing Record 49 of Set 8 | thai binh
# Processing Record 50 of Set 8 | solovetskiy
# Processing Record 1 of Set 9 | ajdabiya
# Processing Record 2 of Set 9 | belyy yar
# Processing Record 3 of Set 9 | pingliang
# Processing Record 4 of Set 9 | kolaras
# Processing Record 5 of Set 9 | moose factory
# Processing Record 6 of Set 9 | ewa beach
# Processing Record 7 of Set 9 | mahebourg
# Processing Record 8 of Set 9 | barbar
# Processing Record 9 of Set 9 | banda aceh
# Processing Record 10 of Set 9 | khuzhir
# Processing Record 11 of Set 9 | olafsvik
# Processing Record 12 of Set 9 | rio gallegos
# Processing Record 13 of Set 9 | kailua
# Processing Record 14 of Set 9 | tumannyy
# Processing Record 15 of Set 9 | marsh harbour
# Processing Record 16 of Set 9 | nemuro
# Processing Record 17 of Set 9 | meulaboh
# Processing Record 18 of Set 9 | puerto penasco
# Processing Record 19 of Set 9 | umm lajj
# Processing Record 20 of Set 9 | tuy hoa
# Processing Record 21 of Set 9 | nalut
# Processing Record 22 of Set 9 | prince rupert
# Processing Record 23 of Set 9 | rocha
# Processing Record 24 of Set 9 | prabumulih
# Processing Record 25 of Set 9 | yian
# Processing Record 26 of Set 9 | duz
# Processing Record 27 of Set 9 | morondava
# Processing Record 28 of Set 9 | youkounkoun
# Processing Record 29 of Set 9 | miramar
# Processing Record 30 of Set 9 | kirakira
# Processing Record 31 of Set 9 | san francisco de macoris
# Processing Record 32 of Set 9 | erfurt
# Processing Record 33 of Set 9 | sint michiel
# Processing Record 34 of Set 9 | sandwick
# Processing Record 35 of Set 9 | caloundra
# Processing Record 36 of Set 9 | jasper
# Processing Record 37 of Set 9 | disna
# Processing Record 38 of Set 9 | mwene-ditu
# Processing Record 39 of Set 9 | restrepo
# Processing Record 40 of Set 9 | mezhdurechensk
# Processing Record 41 of Set 9 | inuvik
# Processing Record 42 of Set 9 | boca do acre
# Processing Record 43 of Set 9 | police
# Processing Record 44 of Set 9 | benjamin constant
# Processing Record 45 of Set 9 | sarangani
# Processing Record 46 of Set 9 | ilo
# Processing Record 47 of Set 9 | lagoa
# Processing Record 48 of Set 9 | anadyr
# Processing Record 49 of Set 9 | ust-kuyga
# Processing Record 50 of Set 9 | lavrentiya
# Processing Record 1 of Set 10 | iqaluit
# Processing Record 2 of Set 10 | oussouye
# Processing Record 3 of Set 10 | jiaonan
# Processing Record 4 of Set 10 | houma
# Processing Record 5 of Set 10 | matay
# Processing Record 6 of Set 10 | alice springs
# Processing Record 7 of Set 10 | svetlaya
# Processing Record 8 of Set 10 | ushtobe
# Processing Record 9 of Set 10 | eyl
# Processing Record 10 of Set 10 | lata
# Processing Record 11 of Set 10 | port keats
# Processing Record 12 of Set 10 | saran
# Processing Record 13 of Set 10 | deputatskiy
# Processing Record 14 of Set 10 | nuuk
# Processing Record 15 of Set 10 | yerbogachen
# Processing Record 16 of Set 10 | muros
# Processing Record 17 of Set 10 | provost
# Processing Record 18 of Set 10 | road town
# Processing Record 19 of Set 10 | atambua
# Processing Record 20 of Set 10 | austin
# Processing Record 21 of Set 10 | wasilla
# Processing Record 22 of Set 10 | jijiga
# Processing Record 23 of Set 10 | san cristobal
# Processing Record 24 of Set 10 | miandrivazo
# Processing Record 25 of Set 10 | elko
# Processing Record 26 of Set 10 | teya
# Processing Record 27 of Set 10 | uray
# Processing Record 28 of Set 10 | cheuskiny
# Processing Record 29 of Set 10 | gornopravdinsk
# Processing Record 30 of Set 10 | djibo
# Processing Record 31 of Set 10 | barra patuca
# Processing Record 32 of Set 10 | lasa
# Processing Record 33 of Set 10 | dali
# Processing Record 34 of Set 10 | panaba
# Processing Record 35 of Set 10 | evensk
# Processing Record 36 of Set 10 | laguna
# Processing Record 37 of Set 10 | klaksvik
# Processing Record 38 of Set 10 | flin flon
# Processing Record 39 of Set 10 | ravar
# Processing Record 40 of Set 10 | birzai
# Processing Record 41 of Set 10 | mosquera
# Processing Record 42 of Set 10 | marinette
# Processing Record 43 of Set 10 | faya
# Processing Record 44 of Set 10 | zyryanovsk
# Processing Record 45 of Set 10 | scarborough
# Processing Record 46 of Set 10 | tabiauea
# Processing Record 47 of Set 10 | zhangye
# Processing Record 48 of Set 10 | puerto baquerizo moreno
# Processing Record 49 of Set 10 | athabasca
# Processing Record 50 of Set 10 | dum duma
# Processing Record 1 of Set 11 | boshnyakovo
# Processing Record 2 of Set 11 | san felipe
# Processing Record 3 of Set 11 | shingu
# Processing Record 4 of Set 11 | mauswagon
# Processing Record 5 of Set 11 | nanhai
# Processing Record 6 of Set 11 | bratsk
# Processing Record 7 of Set 11 | carberry
# Processing Record 8 of Set 11 | cockburn town
# Processing Record 9 of Set 11 | hay river
# Processing Record 10 of Set 11 | sioux lookout
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | zhezkazgan
# Processing Record 13 of Set 11 | mastic beach
# Processing Record 14 of Set 11 | menongue
# Processing Record 15 of Set 11 | soderhamn
# Processing Record 16 of Set 11 | khasan
# Processing Record 17 of Set 11 | tete
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | oyama
# Processing Record 20 of Set 11 | ballina
# Processing Record 21 of Set 11 | zhigansk
# Processing Record 22 of Set 11 | katherine
# Processing Record 23 of Set 11 | qasigiannguit
# Processing Record 24 of Set 11 | wad madani
# Processing Record 25 of Set 11 | tombouctou
# Processing Record 26 of Set 11 | batagay-alyta
# Processing Record 27 of Set 11 | zyryanka
# Processing Record 28 of Set 11 | khandbari
# Processing Record 29 of Set 11 | coari
# Processing Record 30 of Set 11 | maridi
# Processing Record 31 of Set 11 | san juan
# Processing Record 32 of Set 11 | port moresby
# Processing Record 33 of Set 11 | sabha
# Processing Record 34 of Set 11 | tevaitoa
# Processing Record 35 of Set 11 | barbosa ferraz
# Processing Record 36 of Set 11 | homer
# Processing Record 37 of Set 11 | moranbah
# Processing Record 38 of Set 11 | jacareacanga
# Processing Record 39 of Set 11 | adrar
# Processing Record 40 of Set 11 | puro
# Processing Record 41 of Set 11 | ushumun
# Processing Record 42 of Set 11 | estevan
# Processing Record 43 of Set 11 | yar-sale
# Processing Record 44 of Set 11 | san patricio
# Processing Record 45 of Set 11 | caronport
# Processing Record 46 of Set 11 | daxian
# Processing Record 47 of Set 11 | wana
# Processing Record 48 of Set 11 | bemidji
# Processing Record 49 of Set 11 | pinehurst
# Processing Record 50 of Set 11 | burnie
# Processing Record 1 of Set 12 | akyab
# Processing Record 2 of Set 12 | kankaanpaa
# Processing Record 3 of Set 12 | eluru
# Processing Record 4 of Set 12 | kawalu
# Processing Record 5 of Set 12 | half moon bay
# Processing Record 6 of Set 12 | caimito
# Processing Record 7 of Set 12 | wadi musa
# Processing Record 8 of Set 12 | tubruq
# Processing Record 9 of Set 12 | deer lake
# Processing Record 10 of Set 12 | bulgan
# Processing Record 11 of Set 12 | belmonte
# Processing Record 12 of Set 12 | beyneu
# Processing Record 13 of Set 12 | huarmey
# Processing Record 14 of Set 12 | eureka
# Processing Record 15 of Set 12 | honiara
# Processing Record 16 of Set 12 | qovlar
# Processing Record 17 of Set 12 | susangerd
# Processing Record 18 of Set 12 | chirongui
# Processing Record 19 of Set 12 | port shepstone
# Processing Record 20 of Set 12 | lagunas
# Processing Record 21 of Set 12 | savinka
# Processing Record 22 of Set 12 | hobyo
# Processing Record 23 of Set 12 | alindao
# Processing Record 24 of Set 12 | rozivka
# Processing Record 25 of Set 12 | karkaralinsk
# Processing Record 26 of Set 12 | norman wells
# Processing Record 27 of Set 12 | aurangabad
# Processing Record 28 of Set 12 | pokhara
# Processing Record 29 of Set 12 | arlit
# Processing Record 30 of Set 12 | moree
# Processing Record 31 of Set 12 | koutiala
# Processing Record 32 of Set 12 | terrace
# Processing Record 33 of Set 12 | udachnyy
# Processing Record 34 of Set 12 | mandeville
# Processing Record 35 of Set 12 | znamenskoye
# Processing Record 36 of Set 12 | sagua la grande
# Processing Record 37 of Set 12 | richards bay
# Processing Record 38 of Set 12 | heihe
# Processing Record 39 of Set 12 | nara
# Processing Record 40 of Set 12 | kurilsk
# Processing Record 41 of Set 12 | touros
# Processing Record 42 of Set 12 | botwood
# Processing Record 43 of Set 12 | hohhot
# Processing Record 44 of Set 12 | cabra
# Processing Record 45 of Set 12 | naze
# Processing Record 46 of Set 12 | temir
# Processing Record 47 of Set 12 | mattru
# Processing Record 48 of Set 12 | pedernales
# Processing Record 49 of Set 12 | hudiksvall
# Processing Record 50 of Set 12 | matamoros
# Processing Record 1 of Set 13 | sao filipe
# Processing Record 2 of Set 13 | tautira
# Processing Record 3 of Set 13 | bastia
# Processing Record 4 of Set 13 | cheremukhovo
# Processing Record 5 of Set 13 | toora-khem
# Processing Record 6 of Set 13 | quesnel
# Processing Record 7 of Set 13 | maputo
# Processing Record 8 of Set 13 | channel-port aux basques
# Processing Record 9 of Set 13 | nam tha
# Processing Record 10 of Set 13 | culipapa
# Processing Record 11 of Set 13 | santa cruz
# Processing Record 12 of Set 13 | bargal
# Processing Record 13 of Set 13 | sisimiut
# Processing Record 14 of Set 13 | pskov
# Processing Record 15 of Set 13 | vila velha
# Processing Record 16 of Set 13 | sao mateus
# Processing Record 17 of Set 13 | mount isa
# Processing Record 18 of Set 13 | solnechnyy
# Processing Record 19 of Set 13 | labuan
# Processing Record 20 of Set 13 | hofn
# Processing Record 21 of Set 13 | olinda
# Processing Record 22 of Set 13 | cabo rojo
# Processing Record 23 of Set 13 | yanam
# Processing Record 24 of Set 13 | ayni
# Processing Record 25 of Set 13 | portland
# Processing Record 26 of Set 13 | marienburg
# Processing Record 27 of Set 13 | lilongwe
# Processing Record 28 of Set 13 | quechultenango
# Processing Record 29 of Set 13 | jalu
# Processing Record 30 of Set 13 | nantucket
# Processing Record 31 of Set 13 | houston
# Processing Record 32 of Set 13 | matara
# Processing Record 33 of Set 13 | husavik
# Processing Record 34 of Set 13 | barra velha
# Processing Record 35 of Set 13 | port-gentil
# Processing Record 36 of Set 13 | taldan
# Processing Record 37 of Set 13 | amalapuram
# Processing Record 38 of Set 13 | san andres
# Processing Record 39 of Set 13 | luganville
# Processing Record 40 of Set 13 | corrales
# Processing Record 41 of Set 13 | basco
# Processing Record 42 of Set 13 | pulandian
# Processing Record 43 of Set 13 | sal rei
# Processing Record 44 of Set 13 | sofiysk
# Processing Record 45 of Set 13 | tasbuget
# Processing Record 46 of Set 13 | mogadishu
# Processing Record 47 of Set 13 | ekhabi
# Processing Record 48 of Set 13 | ketchikan
# Processing Record 49 of Set 13 | laela
# Processing Record 50 of Set 13 | soyo
# Processing Record 1 of Set 14 | inta
# Processing Record 2 of Set 14 | beya
# Processing Record 3 of Set 14 | murgab
# Processing Record 4 of Set 14 | kuusamo
# Processing Record 5 of Set 14 | stornoway
# Processing Record 6 of Set 14 | impfondo
# Processing Record 7 of Set 14 | safaga
# Processing Record 8 of Set 14 | chaykovskiy
# Processing Record 9 of Set 14 | przeworsk
# Processing Record 10 of Set 14 | talcahuano
# Processing Record 11 of Set 14 | ghanzi
# Processing Record 12 of Set 14 | dubovka
# Processing Record 13 of Set 14 | sunndalsora
# Processing Record 14 of Set 14 | khani
# Processing Record 15 of Set 14 | bouguenais
# Processing Record 16 of Set 14 | sao sebastiao
# Processing Record 17 of Set 14 | brandenburg
# Processing Record 18 of Set 14 | ferme-neuve
# Processing Record 19 of Set 14 | linhai
# Processing Record 20 of Set 14 | genhe
# Processing Record 21 of Set 14 | borgo san dalmazzo
# Processing Record 22 of Set 14 | severomorsk
# Processing Record 23 of Set 14 | sangar
# Processing Record 24 of Set 14 | santa eulalia del rio
# Processing Record 25 of Set 14 | gamboma
# Processing Record 26 of Set 14 | canico
# Processing Record 27 of Set 14 | spearfish
# Processing Record 28 of Set 14 | tahe
# Processing Record 29 of Set 14 | paveh
# Processing Record 30 of Set 14 | ballater
# Processing Record 31 of Set 14 | ngukurr
# Processing Record 32 of Set 14 | sorland
# Processing Record 33 of Set 14 | denpasar
# Processing Record 34 of Set 14 | nevel
# Processing Record 35 of Set 14 | ust-uda
# Processing Record 36 of Set 14 | khovu-aksy
# Processing Record 37 of Set 14 | novouzensk
# Processing Record 38 of Set 14 | sibu
# Processing Record 39 of Set 14 | ladario
# Processing Record 40 of Set 14 | puerto madryn
# Processing Record 41 of Set 14 | bridlington
# Processing Record 42 of Set 14 | bristol
# Processing Record 43 of Set 14 | treinta y tres
# Processing Record 44 of Set 14 | zhangjiakou
# Processing Record 45 of Set 14 | stokmarknes
# Processing Record 46 of Set 14 | mweka
# Processing Record 47 of Set 14 | ulsteinvik
# Processing Record 48 of Set 14 | kieta
# Processing Record 49 of Set 14 | babanusah
# Processing Record 50 of Set 14 | visby
# Processing Record 1 of Set 15 | killam
# Processing Record 2 of Set 15 | tabou
# Processing Record 3 of Set 15 | nikki
# Processing Record 4 of Set 15 | kafr yuba
# Processing Record 5 of Set 15 | round rock
# Processing Record 6 of Set 15 | mackenzie
# Processing Record 7 of Set 15 | berehove
# Processing Record 8 of Set 15 | roma
# Processing Record 9 of Set 15 | moyale
# Processing Record 10 of Set 15 | hinton
# Processing Record 11 of Set 15 | enid
# Processing Record 12 of Set 15 | pestretsy
# Processing Record 13 of Set 15 | amaigbo
# Processing Record 14 of Set 15 | umzimvubu
# Processing Record 15 of Set 15 | padang
# Processing Record 16 of Set 15 | corvallis
# Processing Record 17 of Set 15 | mana
# Processing Record 18 of Set 15 | winnemucca
# Processing Record 19 of Set 15 | hambantota
# Processing Record 20 of Set 15 | yarkovo
# Processing Record 21 of Set 15 | khalkhal
# Processing Record 22 of Set 15 | villacidro
# Processing Record 23 of Set 15 | amudat
# Processing Record 24 of Set 15 | villa oliva
# Processing Record 25 of Set 15 | mecca
# Processing Record 26 of Set 15 | garden city
# Processing Record 27 of Set 15 | magistralnyy
# Processing Record 28 of Set 15 | tilichiki
# Processing Record 29 of Set 15 | mitsamiouli
# Processing Record 30 of Set 15 | morococha
# Processing Record 31 of Set 15 | padre bernardo
# Processing Record 32 of Set 15 | bokspits
# Processing Record 33 of Set 15 | dalaba
# Processing Record 34 of Set 15 | cururupu
# Processing Record 35 of Set 15 | sorvag
# Processing Record 36 of Set 15 | sao jose da coroa grande
# Processing Record 37 of Set 15 | okato
# Processing Record 38 of Set 15 | buqayq
# Processing Record 39 of Set 15 | state college

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0         Verkhniye Tatyshly  56.2912   55.8575     22.78        95
# 1                       Tezu  27.9167   96.1667     55.42        96
# 2                     Albany  42.6001  -73.9662     17.31        75
# 3                   El Limon  10.3059  -67.6321     80.82        50
# 4                     Hobart -42.8794  147.3294     60.03        77
# 5  Petropavlovsk-Kamchatskiy  53.0452  158.6483     18.37        84
# 6              Leningradskiy  69.3833  178.4167    -21.35        96
# 7                      Tiksi  71.6872  128.8694    -20.56        98
# 8                      Xudat  41.6310   48.6810     38.17        72
# 9                      Nigde  37.8333   34.7500     18.61        91
#
#    Cloudiness  Wind Speed Country                 Date Current Description
# 0         100        3.62      RU  2022-02-05 15:10:26     overcast clouds
# 1         100        0.89      IN  2022-02-05 15:10:26          light rain
# 2          18        1.99      US  2022-02-05 15:07:05          few clouds
# 3           1        1.99      VE  2022-02-05 15:10:27           clear sky
# 4         100        4.61      AU  2022-02-05 15:09:23     overcast clouds
# 5         100       11.63      RU  2022-02-05 15:07:26     overcast clouds
# 6           8        5.66      RU  2022-02-05 15:05:43           clear sky
# 7         100        7.38      RU  2022-02-05 15:10:27     overcast clouds
# 8         100       13.00      AZ  2022-02-05 15:10:27     overcast clouds
# 9          10        2.19      TR  2022-02-05 15:10:27           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
